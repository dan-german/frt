# %%
import numpy as np

# %%
mig = np.array([
    [1, 2, 3, 0],
    [4, 5, 6, 1],
    [7, 8, 9, 2],
    [1, 1, 1, 0]
], dtype=float)

kernel = np.array([
    [1, 0, -1],
    [1, 0, -1],
    [1, 0, -1]
], dtype=float)

# %%
width = np.array
res = np.zeros()
res.shape
# Out:
# (2,)
